# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoHyppolito/Estudos/blob/main/Analise_com_pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Continuando o capítulo de análise de dados com pandas**

# %%
# Importando Biblioteca 
import pandas as pd

# %%
df = pd.read_csv("horas_estudadas.csv")

# %%
# primeira visualização
df.head()
# Out:
#      Nome  Segunda  Terça  Quarta  Quinta  Sexta  Sabado  Domingo
# 0  Victor        2      3       1       3      0       0        3
# 1  Amanda        0      3       0       4      3       1        2
# 2    Luis        1      2       4       5      6       0        0
# 3   Júlia        1      1       2       0      0       1        2

# %% [markdown]
# **Aplicando o conceito de funções dentro de um data frame**

# %%
# Utilizando o min(), documentação = DataFrame.min(axis=NoDefault.no_default, skipna=True, level=None, numeric_only=None, **kwargs)
# O parâmetro axis, por padrão escolhe o eixo zero, e podemos também utilizar o 1, vamos ver: 
df.min(axis= 0) # Isso nos retorna o valor mínimo de cada coluna. OBS: na coluna com valor não numérico ; ordem alfabética. 
# Note, que esse comando min(), nada mais é do que uma função que ja está pronta e disponível.
# Out:
# Nome       Amanda
# Segunda         0
# Terça           1
# Quarta          0
# Quinta          0
# Sexta           0
# Sabado          0
# Domingo         0
# dtype: object

# %%
# Vamos comparar com axis=1
df.min(axis=1) # Nesse caso, o min(), observa as linhas.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
# Funções simples: 
def soma(a,b):
  return a + b

# %%
soma(2,3)
# Out:
# 5

# %%
# Função em cima de um df 
def sub_max_min(df):
  return df.max() - df.min() # Agora que a função esta escrita, precisamos aplicar ela em cima de um data frame.

# %%
# Antes de aplicar a nossa função, vamo excluir as informações referentes a nomes, porque não faz sentido. 
df2 = df.drop("Nome", axis=1) # Não confunda esse axis =1, se refere a "linha" de colunas.

# %%
df2.head()
# Out:
#    Segunda  Terça  Quarta  Quinta  Sexta  Sabado  Domingo
# 0        2      3       1       3      0       0        3
# 1        0      3       0       4      3       1        2
# 2        1      2       4       5      6       0        0
# 3        1      1       2       0      0       1        2

# %%
# Para aplicar utilizamos o método apply(), ele aplica uma função dentro de um eixo do meu df. 
#documentação = DataFrame.apply(func, axis=0, raw=False, result_type=None, args=(), **kwargs)
df2.apply(sub_max_min, axis = 0)
# Out:
# Segunda    2
# Terça      2
# Quarta     4
# Quinta     5
# Sexta      6
# Sabado     1
# Domingo    3
# dtype: int64

# %%
# Olha que interessante, como passamos o axis = 0, o computador vai aplicando a nossa função, sub_max_min, em todas as colunas, isto é: 
# Verificando qual o maior valor da coluna, subtraindo pelo menor e nos retornando o resultado.

# %%
# E com axis = 1 
df2.apply(sub_max_min, axis = 1)
# Out:
# 0    3
# 1    4
# 2    6
# 3    2
# dtype: int64

# %%
# Em suma, o método apply(), aplica uma função pré definida ou anonima, como veremos abaixo, com base no EIXO.

# %%
# Um conceito bastante importante, é o de funções anonimas, que basicamente agiliza o processo de aplicar funções, tornando possível, criar uma 
#Função dentro do parâmetro do apply, ao invés de construir uma função antes: 
df2.apply(lambda x: x.max() - x.min(), axis = 0) # Note que é a mesma função criada antes (sub_max_min)
# Out:
# Segunda    2
# Terça      2
# Quarta     4
# Quinta     5
# Sexta      6
# Sabado     1
# Domingo    3
# dtype: int64

# %%
# Agora se desejamos que uma função seja aplicada em cada um dos VALORES do meu df, temos o método applymap(). 
#Documentação = DataFrame.applymap(func, na_action=None, **kwargs) 
df2.applymap(lambda x: str(x) + "Leo")
# Out:
#   Segunda Terça Quarta Quinta Sexta Sabado Domingo
# 0    2Leo  3Leo   1Leo   3Leo  0Leo   0Leo    3Leo
# 1    0Leo  3Leo   0Leo   4Leo  3Leo   1Leo    2Leo
# 2    1Leo  2Leo   4Leo   5Leo  6Leo   0Leo    0Leo
# 3    1Leo  1Leo   2Leo   0Leo  0Leo   1Leo    2Leo

# %%
# Ou seja, a grande diferença do apply(), para o applymap(), é que com o apply, aplicamos a função no eixo, já o applymap, aplica em todos os valores
# E o nosso "x", é o cara que percorre todos os valores do df, poderia ser qualquer outra letra, mas é bastante comum utilizar o x.

# %% [markdown]
# **Indexação hierarquica**

# %%
# Permite que façamos varios tipos de índices, e fazer uma hierarquia entre eles.

# %%
df_fut = pd.read_csv("campeonato-brasileiro-full.csv")

# %%
df_fut.head()
# Out:
#    ID  rodada        data   hora      dia       mandante    visitante  \
# 0   1       1  2003-03-29  16:00   Sabado        Guarani        Vasco
# 1   2       1  2003-03-29  16:00   Sabado   Athletico-PR       Gremio
# 2   3       1  2003-03-30  16:00  Domingo       Flamengo     Coritiba
# 3   4       1  2003-03-30  16:00  Domingo          Goias     Paysandu
# 4   5       1  2003-03-30  16:00  Domingo  Internacional  Ponte Preta
#
#   formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 0               NaN                NaN              NaN               NaN
# 1               NaN                NaN              NaN               NaN
# 2               NaN                NaN              NaN               NaN
# 3               NaN                NaN              NaN               NaN
# 4               NaN                NaN              NaN               NaN
#
#        vencedor             arena  mandante_placar  visitante_placar  \
# 0       Guarani    brinco de ouro                4                 2
# 1  Athletico-PR  arena da baixada                2                 0
# 2             -          maracana                1                 1
# 3             -     serra dourada                2                 2
# 4             -         beira rio                1                 1
#
#   mandante_estado visitante_estado estado_vencedor
# 0              SP               RJ              SP
# 1              PR               RS              PR
# 2              RJ               PR               -
# 3              GO               PA               -
# 4              RS               SP               -

# %%
# Bom para apresentar melhor a ideia de hierarquia dos índices, vamos fazer uma amostra do nosso df, para facilitar
# A nossa compreensão.

# %%
# Para realizar essa asmotra utilizamos o método df.samle; documentação = DataFrame.sample(n=None, frac=None, 
# replace=False, weights=None, random_state=None, axis=None, ignore_index=False)
df_sample =  df_fut.sample(30)

# %%
df_sample.shape
# Out:
# (30, 18)

# %%
df_sample.head() # Observe que os index estão bagunçados, pois a amostra é aleatória.
# Out:
#         ID  rodada        data   hora           dia       mandante  \
# 3081  3082      38  2009-12-06  17:00       Domingo  Internacional
# 4309  4310       9  2013-07-28  16:00       Domingo         Gremio
# 5500  5501      14  2016-07-10  11:00       Domingo       Flamengo
# 4592  4593      37  2013-12-01  18:00       Domingo          Vasco
# 2119  2130      18  2007-08-08  21:45  Quarta-feira          Goias
#
#         visitante formacao_mandante formacao_visitante       tecnico_mandante  \
# 3081  Santo Andre               NaN                NaN                    NaN
# 4309   Fluminense               NaN                NaN                    NaN
# 5500  Atletico-MG           4-2-3-1            4-2-3-1  M. de Oliveira Santos
# 4592      Nautico               NaN                NaN                    NaN
# 2119  Atletico-MG               NaN                NaN                    NaN
#
#           tecnico_visitante       vencedor                         arena  \
# 3081                    NaN  Internacional                     beira rio
# 4309                    NaN         Gremio               arena do gremio
# 5500  M. de Oliveira Santos       Flamengo  estadio nacional de brasilia
# 4592                    NaN          Vasco                      maracana
# 2119                    NaN          Goias                 serra dourada
#
#       mandante_placar  visitante_placar mandante_estado visitante_estado  \
# 3081                4                 1              RS               SP
# 4309                2                 0              RS               RJ
# 5500                2                 0              RJ               MG
# 4592                2                 0              RJ               PE
# 2119                3                 2              GO               MG
#
#      estado_vencedor
# 3081              RS
# 4309              RS
# 5500              RJ
# 4592              RJ
# 2119              GO

# %%
# É possivel escolher o index, na leitura do arquivo csv, com o parâmetro index_col=, porém existe um jeito mais
# prático de se fazer. df.set_index()
#Documentação = DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)

# %%
df_sample.set_index("rodada")
# Out:
#           ID        data   hora            dia       mandante      visitante  \
# rodada
# 38      3082  2009-12-06  17:00        Domingo  Internacional    Santo Andre
# 9       4310  2013-07-28  16:00        Domingo         Gremio     Fluminense
# 14      5501  2016-07-10  11:00        Domingo       Flamengo    Atletico-MG
# 37      4593  2013-12-01  18:00        Domingo          Vasco        Nautico
# 18      2130  2007-08-08  21:45   Quarta-feira          Goias    Atletico-MG
# 7       4676  2014-05-25  18:35        Domingo    Atletico-MG       Criciuma
# 32      3023  2009-10-28  21:50   Quarta-feira      Sao Paulo  Internacional
# 11      3586  2011-10-05  20:30   Quarta-feira         Gremio         Santos
# 30      5284  2015-10-15  19:31   Quinta-feira          Vasco    Chapecoense
# 15      3987  2012-08-08  19:30   Quarta-feira          Sport          Vasco
# 38       998  2004-10-26  20:30    Terça-feira          Goias   Athletico-PR
# 29      5656  2016-10-09  17:02        Domingo    Figueirense    Botafogo-RJ
# 4       5785  2017-06-05  20:00  Segunda-feira          Bahia    Atletico-GO
# 16      6664  2019-08-26  20:00  Segunda-feira    Botafogo-RJ    Chapecoense
# 38      1937  2006-12-02  18:10         Sabado  Internacional          Goias
# 15      5132  2015-07-26  15:59        Domingo    Ponte Preta  Internacional
# 1       3850  2012-05-20  16:00        Domingo    Corinthians     Fluminense
# 4       5405  2016-05-29  18:30        Domingo         Gremio       Coritiba
# 15      5889  2017-07-19  20:59   Quarta-feira    Ponte Preta       Coritiba
# 17      6667  2019-08-31  17:01         Sabado          Bahia            CSA
# 38      6885  2019-12-08  16:01        Domingo      Fortaleza          Bahia
# 33      1462  2005-10-22  16:00         Sabado   Athletico-PR    Atletico-MG
# 22      7481  2021-09-26  16:00        Domingo     Fluminense     Bragantino
# 12      6241  2018-06-13  20:59   Quarta-feira      Palmeiras       Flamengo
# 37      6874  2019-12-05  19:19   Quinta-feira          Bahia          Vasco
# 20      6298  2018-08-22  19:30   Quarta-feira         Parana      Sao Paulo
# 4       6539  2019-05-12  11:00        Domingo       Flamengo    Chapecoense
# 28      2604  2008-10-04  18:20         Sabado         Santos   Athletico-PR
# 28      5259  2015-09-27  11:00        Domingo   Athletico-PR    Ponte Preta
# 17      6294  2018-08-05  19:01        Domingo          Sport    Chapecoense
#
#        formacao_mandante formacao_visitante        tecnico_mandante  \
# rodada
# 38                   NaN                NaN                     NaN
# 9                    NaN                NaN                     NaN
# 14               4-2-3-1            4-2-3-1   M. de Oliveira Santos
# 37                   NaN                NaN                     NaN
# 18                   NaN                NaN                     NaN
# 7                    NaN                NaN                W. Lopes
# 32                   NaN                NaN                     NaN
# 11                   NaN                NaN                     NaN
# 30             4-1-2-1-2            4-2-3-1             A. Ferreira
# 15                   NaN                NaN                     NaN
# 38                   NaN                NaN                     NaN
# 29               4-2-3-1            4-3-1-2      J. Ribeiro Ventura
# 4                4-2-3-1            4-2-3-1         M. Ribeiro Cabo
# 16               4-2-3-1            4-2-3-1             E. Hartkopp
# 38                   NaN                NaN                     NaN
# 15               4-2-3-1            4-2-2-2      D. Aguirre Camblor
# 1                    NaN                NaN                     NaN
# 4                4-2-3-1            4-2-3-1               G. Kleina
# 15               4-2-3-1            4-1-4-1              E. Pacheco
# 17               4-2-3-1              4-4-2                A. Fucks
# 38               4-2-3-1              4-3-3      R. Machado Marques
# 33                   NaN                NaN                     NaN
# 22                 4-3-3            4-2-3-1    M. Nogueira Barbieri
# 12               4-2-3-1            4-1-4-1    M. Nogueira Barbieri
# 37                 4-3-3              4-3-3  V. Luxemburgo da Silva
# 20               4-1-4-1            4-2-3-1      D. Aguirre Camblor
# 4                4-2-3-1            4-2-3-1   N. da Silveira Júnior
# 28                   NaN                NaN                     NaN
# 28               4-2-3-1            4-2-3-1       D. Ghidoni Junior
# 17               4-2-3-1            4-1-4-1               G. Kleina
#
#              tecnico_visitante       vencedor  \
# rodada
# 38                         NaN  Internacional
# 9                          NaN         Gremio
# 14       M. de Oliveira Santos       Flamengo
# 37                         NaN          Vasco
# 18                         NaN          Goias
# 7                     W. Lopes              -
# 32                         NaN      Sao Paulo
# 11                         NaN         Gremio
# 30                 A. Ferreira              -
# 15                         NaN          Vasco
# 38                         NaN          Goias
# 29          J. Ribeiro Ventura    Botafogo-RJ
# 4              M. Ribeiro Cabo          Bahia
# 16                 E. Hartkopp              -
# 38                         NaN          Goias
# 15          D. Aguirre Camblor              -
# 1                          NaN     Fluminense
# 4                    G. Kleina         Gremio
# 15                  E. Pacheco    Ponte Preta
# 17                    A. Fucks          Bahia
# 38          R. Machado Marques      Fortaleza
# 33                         NaN   Athletico-PR
# 22        M. Nogueira Barbieri     Fluminense
# 12        M. Nogueira Barbieri              -
# 37      V. Luxemburgo da Silva              -
# 20          D. Aguirre Camblor              -
# 4        N. da Silveira Júnior       Flamengo
# 28                         NaN         Santos
# 28           D. Ghidoni Junior    Ponte Preta
# 17                   G. Kleina              -
#
#                                     arena  mandante_placar  visitante_placar  \
# rodada
# 38                              beira rio                4                 1
# 9                         arena do gremio                2                 0
# 14           estadio nacional de brasilia                2                 0
# 37                               maracana                2                 0
# 18                          serra dourada                3                 2
# 7                       estadio ipatingao                0                 0
# 32                                morumbi                1                 0
# 11                               olimpico                1                 0
# 30                               maracana                1                 1
# 15                         ilha do retiro                0                 2
# 38                          serra dourada                2                 0
# 29                      orlando scarpelli                0                 1
# 4               itaipava arena fonte nova                3                 0
# 16                  estadio nilton santos                0                 0
# 38                              beira rio                1                 4
# 15                       moises lucarelli                0                 0
# 1                                pacaembu                0                 1
# 4                         arena do gremio                2                 0
# 15                       moises lucarelli                4                 0
# 17              itaipava arena fonte nova                1                 0
# 38                         arena castelao                2                 1
# 33                       arena da baixada                2                 0
# 22                               maracana                2                 1
# 12                         allianz parque                1                 1
# 37              itaipava arena fonte nova                1                 1
# 20                          vila capanema                1                 1
# 4                                maracana                2                 1
# 28                           vila belmiro                4                 0
# 28      estadio joaquim americo guimaraes                1                 2
# 17              adelmar da costa carvalho                1                 1
#
#        mandante_estado visitante_estado estado_vencedor
# rodada
# 38                  RS               SP              RS
# 9                   RS               RJ              RS
# 14                  RJ               MG              RJ
# 37                  RJ               PE              RJ
# 18                  GO               MG              GO
# 7                   MG               SC               -
# 32                  SP               RS              SP
# 11                  RS               SP              RS
# 30                  RJ               SC               -
# 15                  PE               RJ              RJ
# 38                  GO               PR              GO
# 29                  SC               RJ              RJ
# 4                   BA               GO              BA
# 16                  RJ               SC               -
# 38                  RS               GO              GO
# 15                  SP               RS               -
# 1                   SP               RJ              RJ
# 4                   RS               PR              RS
# 15                  SP               PR              SP
# 17                  BA               AL              BA
# 38                  CE               BA              CE
# 33                  PR               MG              PR
# 22                  RJ               SP              RJ
# 12                  SP               RJ               -
# 37                  BA               RJ               -
# 20                  PR               SP               -
# 4                   RJ               SC              RJ
# 28                  SP               PR              SP
# 28                  PR               SP              SP
# 17                  PE               SC               -

# %%
# O interessante é a possibilidade de escolher mais de um index, utilizando uma lista 
df_sample.set_index(["rodada", "dia"], inplace=True)

# %%
df_sample.head()
# Out:
#                        ID        data   hora       mandante    visitante  \
# rodada dia
# 38     Domingo       3082  2009-12-06  17:00  Internacional  Santo Andre
# 9      Domingo       4310  2013-07-28  16:00         Gremio   Fluminense
# 14     Domingo       5501  2016-07-10  11:00       Flamengo  Atletico-MG
# 37     Domingo       4593  2013-12-01  18:00          Vasco      Nautico
# 18     Quarta-feira  2130  2007-08-08  21:45          Goias  Atletico-MG
#
#                     formacao_mandante formacao_visitante  \
# rodada dia
# 38     Domingo                    NaN                NaN
# 9      Domingo                    NaN                NaN
# 14     Domingo                4-2-3-1            4-2-3-1
# 37     Domingo                    NaN                NaN
# 18     Quarta-feira               NaN                NaN
#
#                           tecnico_mandante      tecnico_visitante  \
# rodada dia
# 38     Domingo                         NaN                    NaN
# 9      Domingo                         NaN                    NaN
# 14     Domingo       M. de Oliveira Santos  M. de Oliveira Santos
# 37     Domingo                         NaN                    NaN
# 18     Quarta-feira                    NaN                    NaN
#
#                           vencedor                         arena  \
# rodada dia
# 38     Domingo       Internacional                     beira rio
# 9      Domingo              Gremio               arena do gremio
# 14     Domingo            Flamengo  estadio nacional de brasilia
# 37     Domingo               Vasco                      maracana
# 18     Quarta-feira          Goias                 serra dourada
#
#                      mandante_placar  visitante_placar mandante_estado  \
# rodada dia
# 38     Domingo                     4                 1              RS
# 9      Domingo                     2                 0              RS
# 14     Domingo                     2                 0              RJ
# 37     Domingo                     2                 0              RJ
# 18     Quarta-feira                3                 2              GO
#
#                     visitante_estado estado_vencedor
# rodada dia
# 38     Domingo                    SP              RS
# 9      Domingo                    RJ              RS
# 14     Domingo                    MG              RJ
# 37     Domingo                    PE              RJ
# 18     Quarta-feira               MG              GO

# %%
# Outra coisa interessante, é fazer um sort_index(), para ordenar os index, e utilizar o parâmetro ascending= true/false para escolher a ordenação.
df_sample.sort_index() # no caso de mais index, basta passar o ascending em lista[true,false]
# Out:
#                         ID        data   hora       mandante      visitante  \
# rodada dia
# 1      Domingo        3850  2012-05-20  16:00    Corinthians     Fluminense
# 4      Domingo        5405  2016-05-29  18:30         Gremio       Coritiba
#        Domingo        6539  2019-05-12  11:00       Flamengo    Chapecoense
#        Segunda-feira  5785  2017-06-05  20:00          Bahia    Atletico-GO
# 7      Domingo        4676  2014-05-25  18:35    Atletico-MG       Criciuma
# 9      Domingo        4310  2013-07-28  16:00         Gremio     Fluminense
# 11     Quarta-feira   3586  2011-10-05  20:30         Gremio         Santos
# 12     Quarta-feira   6241  2018-06-13  20:59      Palmeiras       Flamengo
# 14     Domingo        5501  2016-07-10  11:00       Flamengo    Atletico-MG
# 15     Domingo        5132  2015-07-26  15:59    Ponte Preta  Internacional
#        Quarta-feira   3987  2012-08-08  19:30          Sport          Vasco
#        Quarta-feira   5889  2017-07-19  20:59    Ponte Preta       Coritiba
# 16     Segunda-feira  6664  2019-08-26  20:00    Botafogo-RJ    Chapecoense
# 17     Domingo        6294  2018-08-05  19:01          Sport    Chapecoense
#        Sabado         6667  2019-08-31  17:01          Bahia            CSA
# 18     Quarta-feira   2130  2007-08-08  21:45          Goias    Atletico-MG
# 20     Quarta-feira   6298  2018-08-22  19:30         Parana      Sao Paulo
# 22     Domingo        7481  2021-09-26  16:00     Fluminense     Bragantino
# 28     Domingo        5259  2015-09-27  11:00   Athletico-PR    Ponte Preta
#        Sabado         2604  2008-10-04  18:20         Santos   Athletico-PR
# 29     Domingo        5656  2016-10-09  17:02    Figueirense    Botafogo-RJ
# 30     Quinta-feira   5284  2015-10-15  19:31          Vasco    Chapecoense
# 32     Quarta-feira   3023  2009-10-28  21:50      Sao Paulo  Internacional
# 33     Sabado         1462  2005-10-22  16:00   Athletico-PR    Atletico-MG
# 37     Domingo        4593  2013-12-01  18:00          Vasco        Nautico
#        Quinta-feira   6874  2019-12-05  19:19          Bahia          Vasco
# 38     Domingo        3082  2009-12-06  17:00  Internacional    Santo Andre
#        Domingo        6885  2019-12-08  16:01      Fortaleza          Bahia
#        Sabado         1937  2006-12-02  18:10  Internacional          Goias
#        Terça-feira     998  2004-10-26  20:30          Goias   Athletico-PR
#
#                      formacao_mandante formacao_visitante  \
# rodada dia
# 1      Domingo                     NaN                NaN
# 4      Domingo                 4-2-3-1            4-2-3-1
#        Domingo                 4-2-3-1            4-2-3-1
#        Segunda-feira           4-2-3-1            4-2-3-1
# 7      Domingo                     NaN                NaN
# 9      Domingo                     NaN                NaN
# 11     Quarta-feira                NaN                NaN
# 12     Quarta-feira            4-2-3-1            4-1-4-1
# 14     Domingo                 4-2-3-1            4-2-3-1
# 15     Domingo                 4-2-3-1            4-2-2-2
#        Quarta-feira                NaN                NaN
#        Quarta-feira            4-2-3-1            4-1-4-1
# 16     Segunda-feira           4-2-3-1            4-2-3-1
# 17     Domingo                 4-2-3-1            4-1-4-1
#        Sabado                  4-2-3-1              4-4-2
# 18     Quarta-feira                NaN                NaN
# 20     Quarta-feira            4-1-4-1            4-2-3-1
# 22     Domingo                   4-3-3            4-2-3-1
# 28     Domingo                 4-2-3-1            4-2-3-1
#        Sabado                      NaN                NaN
# 29     Domingo                 4-2-3-1            4-3-1-2
# 30     Quinta-feira          4-1-2-1-2            4-2-3-1
# 32     Quarta-feira                NaN                NaN
# 33     Sabado                      NaN                NaN
# 37     Domingo                     NaN                NaN
#        Quinta-feira              4-3-3              4-3-3
# 38     Domingo                     NaN                NaN
#        Domingo                 4-2-3-1              4-3-3
#        Sabado                      NaN                NaN
#        Terça-feira                 NaN                NaN
#
#                             tecnico_mandante       tecnico_visitante  \
# rodada dia
# 1      Domingo                           NaN                     NaN
# 4      Domingo                     G. Kleina               G. Kleina
#        Domingo         N. da Silveira Júnior   N. da Silveira Júnior
#        Segunda-feira         M. Ribeiro Cabo         M. Ribeiro Cabo
# 7      Domingo                      W. Lopes                W. Lopes
# 9      Domingo                           NaN                     NaN
# 11     Quarta-feira                      NaN                     NaN
# 12     Quarta-feira     M. Nogueira Barbieri    M. Nogueira Barbieri
# 14     Domingo         M. de Oliveira Santos   M. de Oliveira Santos
# 15     Domingo            D. Aguirre Camblor      D. Aguirre Camblor
#        Quarta-feira                      NaN                     NaN
#        Quarta-feira               E. Pacheco              E. Pacheco
# 16     Segunda-feira             E. Hartkopp             E. Hartkopp
# 17     Domingo                     G. Kleina               G. Kleina
#        Sabado                       A. Fucks                A. Fucks
# 18     Quarta-feira                      NaN                     NaN
# 20     Quarta-feira       D. Aguirre Camblor      D. Aguirre Camblor
# 22     Domingo          M. Nogueira Barbieri    M. Nogueira Barbieri
# 28     Domingo             D. Ghidoni Junior       D. Ghidoni Junior
#        Sabado                            NaN                     NaN
# 29     Domingo            J. Ribeiro Ventura      J. Ribeiro Ventura
# 30     Quinta-feira              A. Ferreira             A. Ferreira
# 32     Quarta-feira                      NaN                     NaN
# 33     Sabado                            NaN                     NaN
# 37     Domingo                           NaN                     NaN
#        Quinta-feira   V. Luxemburgo da Silva  V. Luxemburgo da Silva
# 38     Domingo                           NaN                     NaN
#        Domingo            R. Machado Marques      R. Machado Marques
#        Sabado                            NaN                     NaN
#        Terça-feira                       NaN                     NaN
#
#                            vencedor                              arena  \
# rodada dia
# 1      Domingo           Fluminense                           pacaembu
# 4      Domingo               Gremio                    arena do gremio
#        Domingo             Flamengo                           maracana
#        Segunda-feira          Bahia          itaipava arena fonte nova
# 7      Domingo                    -                  estadio ipatingao
# 9      Domingo               Gremio                    arena do gremio
# 11     Quarta-feira          Gremio                           olimpico
# 12     Quarta-feira               -                     allianz parque
# 14     Domingo             Flamengo       estadio nacional de brasilia
# 15     Domingo                    -                   moises lucarelli
#        Quarta-feira           Vasco                     ilha do retiro
#        Quarta-feira     Ponte Preta                   moises lucarelli
# 16     Segunda-feira              -              estadio nilton santos
# 17     Domingo                    -          adelmar da costa carvalho
#        Sabado                 Bahia          itaipava arena fonte nova
# 18     Quarta-feira           Goias                      serra dourada
# 20     Quarta-feira               -                      vila capanema
# 22     Domingo           Fluminense                           maracana
# 28     Domingo          Ponte Preta  estadio joaquim americo guimaraes
#        Sabado                Santos                       vila belmiro
# 29     Domingo          Botafogo-RJ                  orlando scarpelli
# 30     Quinta-feira               -                           maracana
# 32     Quarta-feira       Sao Paulo                            morumbi
# 33     Sabado          Athletico-PR                   arena da baixada
# 37     Domingo                Vasco                           maracana
#        Quinta-feira               -          itaipava arena fonte nova
# 38     Domingo        Internacional                          beira rio
#        Domingo            Fortaleza                     arena castelao
#        Sabado                 Goias                          beira rio
#        Terça-feira            Goias                      serra dourada
#
#                       mandante_placar  visitante_placar mandante_estado  \
# rodada dia
# 1      Domingo                      0                 1              SP
# 4      Domingo                      2                 0              RS
#        Domingo                      2                 1              RJ
#        Segunda-feira                3                 0              BA
# 7      Domingo                      0                 0              MG
# 9      Domingo                      2                 0              RS
# 11     Quarta-feira                 1                 0              RS
# 12     Quarta-feira                 1                 1              SP
# 14     Domingo                      2                 0              RJ
# 15     Domingo                      0                 0              SP
#        Quarta-feira                 0                 2              PE
#        Quarta-feira                 4                 0              SP
# 16     Segunda-feira                0                 0              RJ
# 17     Domingo                      1                 1              PE
#        Sabado                       1                 0              BA
# 18     Quarta-feira                 3                 2              GO
# 20     Quarta-feira                 1                 1              PR
# 22     Domingo                      2                 1              RJ
# 28     Domingo                      1                 2              PR
#        Sabado                       4                 0              SP
# 29     Domingo                      0                 1              SC
# 30     Quinta-feira                 1                 1              RJ
# 32     Quarta-feira                 1                 0              SP
# 33     Sabado                       2                 0              PR
# 37     Domingo                      2                 0              RJ
#        Quinta-feira                 1                 1              BA
# 38     Domingo                      4                 1              RS
#        Domingo                      2                 1              CE
#        Sabado                       1                 4              RS
#        Terça-feira                  2                 0              GO
#
#                      visitante_estado estado_vencedor
# rodada dia
# 1      Domingo                     RJ              RJ
# 4      Domingo                     PR              RS
#        Domingo                     SC              RJ
#        Segunda-feira               GO              BA
# 7      Domingo                     SC               -
# 9      Domingo                     RJ              RS
# 11     Quarta-feira                SP              RS
# 12     Quarta-feira                RJ               -
# 14     Domingo                     MG              RJ
# 15     Domingo                     RS               -
#        Quarta-feira                RJ              RJ
#        Quarta-feira                PR              SP
# 16     Segunda-feira               SC               -
# 17     Domingo                     SC               -
#        Sabado                      AL              BA
# 18     Quarta-feira                MG              GO
# 20     Quarta-feira                SP               -
# 22     Domingo                     SP              RJ
# 28     Domingo                     SP              SP
#        Sabado                      PR              SP
# 29     Domingo                     RJ              RJ
# 30     Quinta-feira                SC               -
# 32     Quarta-feira                RS              SP
# 33     Sabado                      MG              PR
# 37     Domingo                     PE              RJ
#        Quinta-feira                RJ               -
# 38     Domingo                     SP              RS
#        Domingo                     BA              CE
#        Sabado                      GO              GO
#        Terça-feira                 PR              GO

# %%
# Após a analise podemos resetar o  nosso index, utilizando o .reset_index()
df_sample.reset_index(inplace=True)

# %%
# Agora quero analisar, se o dia que ocorre a partida influencia na quantidade de gols que o mandante placar faz, isso porque em dias de semana 
# Normalmente tem menos torcida, então basicamente estamos fazendo uma análise da influência da quantidade de torcida no numero de gols. 
df_sample.set_index(["dia" , "mandante_placar"], inplace=True)

# %%
df_sample.head(30) # Visualizar informações da amostra.
# Out:
#                                rodada    ID        data   hora       mandante  \
# dia           mandante_placar
# Domingo       4                    38  3082  2009-12-06  17:00  Internacional
#               2                     9  4310  2013-07-28  16:00         Gremio
#               2                    14  5501  2016-07-10  11:00       Flamengo
#               2                    37  4593  2013-12-01  18:00          Vasco
# Quarta-feira  3                    18  2130  2007-08-08  21:45          Goias
# Domingo       0                     7  4676  2014-05-25  18:35    Atletico-MG
# Quarta-feira  1                    32  3023  2009-10-28  21:50      Sao Paulo
#               1                    11  3586  2011-10-05  20:30         Gremio
# Quinta-feira  1                    30  5284  2015-10-15  19:31          Vasco
# Quarta-feira  0                    15  3987  2012-08-08  19:30          Sport
# Terça-feira   2                    38   998  2004-10-26  20:30          Goias
# Domingo       0                    29  5656  2016-10-09  17:02    Figueirense
# Segunda-feira 3                     4  5785  2017-06-05  20:00          Bahia
#               0                    16  6664  2019-08-26  20:00    Botafogo-RJ
# Sabado        1                    38  1937  2006-12-02  18:10  Internacional
# Domingo       0                    15  5132  2015-07-26  15:59    Ponte Preta
#               0                     1  3850  2012-05-20  16:00    Corinthians
#               2                     4  5405  2016-05-29  18:30         Gremio
# Quarta-feira  4                    15  5889  2017-07-19  20:59    Ponte Preta
# Sabado        1                    17  6667  2019-08-31  17:01          Bahia
# Domingo       2                    38  6885  2019-12-08  16:01      Fortaleza
# Sabado        2                    33  1462  2005-10-22  16:00   Athletico-PR
# Domingo       2                    22  7481  2021-09-26  16:00     Fluminense
# Quarta-feira  1                    12  6241  2018-06-13  20:59      Palmeiras
# Quinta-feira  1                    37  6874  2019-12-05  19:19          Bahia
# Quarta-feira  1                    20  6298  2018-08-22  19:30         Parana
# Domingo       2                     4  6539  2019-05-12  11:00       Flamengo
# Sabado        4                    28  2604  2008-10-04  18:20         Santos
# Domingo       1                    28  5259  2015-09-27  11:00   Athletico-PR
#               1                    17  6294  2018-08-05  19:01          Sport
#
#                                    visitante formacao_mandante  \
# dia           mandante_placar
# Domingo       4                  Santo Andre               NaN
#               2                   Fluminense               NaN
#               2                  Atletico-MG           4-2-3-1
#               2                      Nautico               NaN
# Quarta-feira  3                  Atletico-MG               NaN
# Domingo       0                     Criciuma               NaN
# Quarta-feira  1                Internacional               NaN
#               1                       Santos               NaN
# Quinta-feira  1                  Chapecoense         4-1-2-1-2
# Quarta-feira  0                        Vasco               NaN
# Terça-feira   2                 Athletico-PR               NaN
# Domingo       0                  Botafogo-RJ           4-2-3-1
# Segunda-feira 3                  Atletico-GO           4-2-3-1
#               0                  Chapecoense           4-2-3-1
# Sabado        1                        Goias               NaN
# Domingo       0                Internacional           4-2-3-1
#               0                   Fluminense               NaN
#               2                     Coritiba           4-2-3-1
# Quarta-feira  4                     Coritiba           4-2-3-1
# Sabado        1                          CSA           4-2-3-1
# Domingo       2                        Bahia           4-2-3-1
# Sabado        2                  Atletico-MG               NaN
# Domingo       2                   Bragantino             4-3-3
# Quarta-feira  1                     Flamengo           4-2-3-1
# Quinta-feira  1                        Vasco             4-3-3
# Quarta-feira  1                    Sao Paulo           4-1-4-1
# Domingo       2                  Chapecoense           4-2-3-1
# Sabado        4                 Athletico-PR               NaN
# Domingo       1                  Ponte Preta           4-2-3-1
#               1                  Chapecoense           4-2-3-1
#
#                               formacao_visitante        tecnico_mandante  \
# dia           mandante_placar
# Domingo       4                              NaN                     NaN
#               2                              NaN                     NaN
#               2                          4-2-3-1   M. de Oliveira Santos
#               2                              NaN                     NaN
# Quarta-feira  3                              NaN                     NaN
# Domingo       0                              NaN                W. Lopes
# Quarta-feira  1                              NaN                     NaN
#               1                              NaN                     NaN
# Quinta-feira  1                          4-2-3-1             A. Ferreira
# Quarta-feira  0                              NaN                     NaN
# Terça-feira   2                              NaN                     NaN
# Domingo       0                          4-3-1-2      J. Ribeiro Ventura
# Segunda-feira 3                          4-2-3-1         M. Ribeiro Cabo
#               0                          4-2-3-1             E. Hartkopp
# Sabado        1                              NaN                     NaN
# Domingo       0                          4-2-2-2      D. Aguirre Camblor
#               0                              NaN                     NaN
#               2                          4-2-3-1               G. Kleina
# Quarta-feira  4                          4-1-4-1              E. Pacheco
# Sabado        1                            4-4-2                A. Fucks
# Domingo       2                            4-3-3      R. Machado Marques
# Sabado        2                              NaN                     NaN
# Domingo       2                          4-2-3-1    M. Nogueira Barbieri
# Quarta-feira  1                          4-1-4-1    M. Nogueira Barbieri
# Quinta-feira  1                            4-3-3  V. Luxemburgo da Silva
# Quarta-feira  1                          4-2-3-1      D. Aguirre Camblor
# Domingo       2                          4-2-3-1   N. da Silveira Júnior
# Sabado        4                              NaN                     NaN
# Domingo       1                          4-2-3-1       D. Ghidoni Junior
#               1                          4-1-4-1               G. Kleina
#
#                                     tecnico_visitante       vencedor  \
# dia           mandante_placar
# Domingo       4                                   NaN  Internacional
#               2                                   NaN         Gremio
#               2                 M. de Oliveira Santos       Flamengo
#               2                                   NaN          Vasco
# Quarta-feira  3                                   NaN          Goias
# Domingo       0                              W. Lopes              -
# Quarta-feira  1                                   NaN      Sao Paulo
#               1                                   NaN         Gremio
# Quinta-feira  1                           A. Ferreira              -
# Quarta-feira  0                                   NaN          Vasco
# Terça-feira   2                                   NaN          Goias
# Domingo       0                    J. Ribeiro Ventura    Botafogo-RJ
# Segunda-feira 3                       M. Ribeiro Cabo          Bahia
#               0                           E. Hartkopp              -
# Sabado        1                                   NaN          Goias
# Domingo       0                    D. Aguirre Camblor              -
#               0                                   NaN     Fluminense
#               2                             G. Kleina         Gremio
# Quarta-feira  4                            E. Pacheco    Ponte Preta
# Sabado        1                              A. Fucks          Bahia
# Domingo       2                    R. Machado Marques      Fortaleza
# Sabado        2                                   NaN   Athletico-PR
# Domingo       2                  M. Nogueira Barbieri     Fluminense
# Quarta-feira  1                  M. Nogueira Barbieri              -
# Quinta-feira  1                V. Luxemburgo da Silva              -
# Quarta-feira  1                    D. Aguirre Camblor              -
# Domingo       2                 N. da Silveira Júnior       Flamengo
# Sabado        4                                   NaN         Santos
# Domingo       1                     D. Ghidoni Junior    Ponte Preta
#               1                             G. Kleina              -
#
#                                                            arena  \
# dia           mandante_placar
# Domingo       4                                        beira rio
#               2                                  arena do gremio
#               2                     estadio nacional de brasilia
#               2                                         maracana
# Quarta-feira  3                                    serra dourada
# Domingo       0                                estadio ipatingao
# Quarta-feira  1                                          morumbi
#               1                                         olimpico
# Quinta-feira  1                                         maracana
# Quarta-feira  0                                   ilha do retiro
# Terça-feira   2                                    serra dourada
# Domingo       0                                orlando scarpelli
# Segunda-feira 3                        itaipava arena fonte nova
#               0                            estadio nilton santos
# Sabado        1                                        beira rio
# Domingo       0                                 moises lucarelli
#               0                                         pacaembu
#               2                                  arena do gremio
# Quarta-feira  4                                 moises lucarelli
# Sabado        1                        itaipava arena fonte nova
# Domingo       2                                   arena castelao
# Sabado        2                                 arena da baixada
# Domingo       2                                         maracana
# Quarta-feira  1                                   allianz parque
# Quinta-feira  1                        itaipava arena fonte nova
# Quarta-feira  1                                    vila capanema
# Domingo       2                                         maracana
# Sabado        4                                     vila belmiro
# Domingo       1                estadio joaquim americo guimaraes
#               1                        adelmar da costa carvalho
#
#                                visitante_placar mandante_estado  \
# dia           mandante_placar
# Domingo       4                               1              RS
#               2                               0              RS
#               2                               0              RJ
#               2                               0              RJ
# Quarta-feira  3                               2              GO
# Domingo       0                               0              MG
# Quarta-feira  1                               0              SP
#               1                               0              RS
# Quinta-feira  1                               1              RJ
# Quarta-feira  0                               2              PE
# Terça-feira   2                               0              GO
# Domingo       0                               1              SC
# Segunda-feira 3                               0              BA
#               0                               0              RJ
# Sabado        1                               4              RS
# Domingo       0                               0              SP
#               0                               1              SP
#               2                               0              RS
# Quarta-feira  4                               0              SP
# Sabado        1                               0              BA
# Domingo       2                               1              CE
# Sabado        2                               0              PR
# Domingo       2                               1              RJ
# Quarta-feira  1                               1              SP
# Quinta-feira  1                               1              BA
# Quarta-feira  1                               1              PR
# Domingo       2                               1              RJ
# Sabado        4                               0              SP
# Domingo       1                               2              PR
#               1                               1              PE
#
#                               visitante_estado estado_vencedor
# dia           mandante_placar
# Domingo       4                             SP              RS
#               2                             RJ              RS
#               2                             MG              RJ
#               2                             PE              RJ
# Quarta-feira  3                             MG              GO
# Domingo       0                             SC               -
# Quarta-feira  1                             RS              SP
#               1                             SP              RS
# Quinta-feira  1                             SC               -
# Quarta-feira  0                             RJ              RJ
# Terça-feira   2                             PR              GO
# Domingo       0                             RJ              RJ
# Segunda-feira 3                             GO              BA
#               0                             SC               -
# Sabado        1                             GO              GO
# Domingo       0                             RS               -
#               0                             RJ              RJ
#               2                             PR              RS
# Quarta-feira  4                             PR              SP
# Sabado        1                             AL              BA
# Domingo       2                             BA              CE
# Sabado        2                             MG              PR
# Domingo       2                             SP              RJ
# Quarta-feira  1                             RJ               -
# Quinta-feira  1                             RJ               -
# Quarta-feira  1                             SP               -
# Domingo       2                             SC              RJ
# Sabado        4                             PR              SP
# Domingo       1                             SP              SP
#               1                             SC               -

# %%
df_sample.sort_index(inplace=True)# Organizando para facilitar a visualização, e salvando a ordenação do dataFrame.

# %%
df_sample.head(30) # Visualizando organizado
# Out:
#                                rodada    ID        data   hora       mandante  \
# dia           mandante_placar
# Domingo       0                     7  4676  2014-05-25  18:35    Atletico-MG
#               0                    29  5656  2016-10-09  17:02    Figueirense
#               0                    15  5132  2015-07-26  15:59    Ponte Preta
#               0                     1  3850  2012-05-20  16:00    Corinthians
#               1                    28  5259  2015-09-27  11:00   Athletico-PR
#               1                    17  6294  2018-08-05  19:01          Sport
#               2                     9  4310  2013-07-28  16:00         Gremio
#               2                    14  5501  2016-07-10  11:00       Flamengo
#               2                    37  4593  2013-12-01  18:00          Vasco
#               2                     4  5405  2016-05-29  18:30         Gremio
#               2                    38  6885  2019-12-08  16:01      Fortaleza
#               2                    22  7481  2021-09-26  16:00     Fluminense
#               2                     4  6539  2019-05-12  11:00       Flamengo
#               4                    38  3082  2009-12-06  17:00  Internacional
# Quarta-feira  0                    15  3987  2012-08-08  19:30          Sport
#               1                    32  3023  2009-10-28  21:50      Sao Paulo
#               1                    11  3586  2011-10-05  20:30         Gremio
#               1                    12  6241  2018-06-13  20:59      Palmeiras
#               1                    20  6298  2018-08-22  19:30         Parana
#               3                    18  2130  2007-08-08  21:45          Goias
#               4                    15  5889  2017-07-19  20:59    Ponte Preta
# Quinta-feira  1                    30  5284  2015-10-15  19:31          Vasco
#               1                    37  6874  2019-12-05  19:19          Bahia
# Sabado        1                    38  1937  2006-12-02  18:10  Internacional
#               1                    17  6667  2019-08-31  17:01          Bahia
#               2                    33  1462  2005-10-22  16:00   Athletico-PR
#               4                    28  2604  2008-10-04  18:20         Santos
# Segunda-feira 0                    16  6664  2019-08-26  20:00    Botafogo-RJ
#               3                     4  5785  2017-06-05  20:00          Bahia
# Terça-feira   2                    38   998  2004-10-26  20:30          Goias
#
#                                    visitante formacao_mandante  \
# dia           mandante_placar
# Domingo       0                     Criciuma               NaN
#               0                  Botafogo-RJ           4-2-3-1
#               0                Internacional           4-2-3-1
#               0                   Fluminense               NaN
#               1                  Ponte Preta           4-2-3-1
#               1                  Chapecoense           4-2-3-1
#               2                   Fluminense               NaN
#               2                  Atletico-MG           4-2-3-1
#               2                      Nautico               NaN
#               2                     Coritiba           4-2-3-1
#               2                        Bahia           4-2-3-1
#               2                   Bragantino             4-3-3
#               2                  Chapecoense           4-2-3-1
#               4                  Santo Andre               NaN
# Quarta-feira  0                        Vasco               NaN
#               1                Internacional               NaN
#               1                       Santos               NaN
#               1                     Flamengo           4-2-3-1
#               1                    Sao Paulo           4-1-4-1
#               3                  Atletico-MG               NaN
#               4                     Coritiba           4-2-3-1
# Quinta-feira  1                  Chapecoense         4-1-2-1-2
#               1                        Vasco             4-3-3
# Sabado        1                        Goias               NaN
#               1                          CSA           4-2-3-1
#               2                  Atletico-MG               NaN
#               4                 Athletico-PR               NaN
# Segunda-feira 0                  Chapecoense           4-2-3-1
#               3                  Atletico-GO           4-2-3-1
# Terça-feira   2                 Athletico-PR               NaN
#
#                               formacao_visitante        tecnico_mandante  \
# dia           mandante_placar
# Domingo       0                              NaN                W. Lopes
#               0                          4-3-1-2      J. Ribeiro Ventura
#               0                          4-2-2-2      D. Aguirre Camblor
#               0                              NaN                     NaN
#               1                          4-2-3-1       D. Ghidoni Junior
#               1                          4-1-4-1               G. Kleina
#               2                              NaN                     NaN
#               2                          4-2-3-1   M. de Oliveira Santos
#               2                              NaN                     NaN
#               2                          4-2-3-1               G. Kleina
#               2                            4-3-3      R. Machado Marques
#               2                          4-2-3-1    M. Nogueira Barbieri
#               2                          4-2-3-1   N. da Silveira Júnior
#               4                              NaN                     NaN
# Quarta-feira  0                              NaN                     NaN
#               1                              NaN                     NaN
#               1                              NaN                     NaN
#               1                          4-1-4-1    M. Nogueira Barbieri
#               1                          4-2-3-1      D. Aguirre Camblor
#               3                              NaN                     NaN
#               4                          4-1-4-1              E. Pacheco
# Quinta-feira  1                          4-2-3-1             A. Ferreira
#               1                            4-3-3  V. Luxemburgo da Silva
# Sabado        1                              NaN                     NaN
#               1                            4-4-2                A. Fucks
#               2                              NaN                     NaN
#               4                              NaN                     NaN
# Segunda-feira 0                          4-2-3-1             E. Hartkopp
#               3                          4-2-3-1         M. Ribeiro Cabo
# Terça-feira   2                              NaN                     NaN
#
#                                     tecnico_visitante       vencedor  \
# dia           mandante_placar
# Domingo       0                              W. Lopes              -
#               0                    J. Ribeiro Ventura    Botafogo-RJ
#               0                    D. Aguirre Camblor              -
#               0                                   NaN     Fluminense
#               1                     D. Ghidoni Junior    Ponte Preta
#               1                             G. Kleina              -
#               2                                   NaN         Gremio
#               2                 M. de Oliveira Santos       Flamengo
#               2                                   NaN          Vasco
#               2                             G. Kleina         Gremio
#               2                    R. Machado Marques      Fortaleza
#               2                  M. Nogueira Barbieri     Fluminense
#               2                 N. da Silveira Júnior       Flamengo
#               4                                   NaN  Internacional
# Quarta-feira  0                                   NaN          Vasco
#               1                                   NaN      Sao Paulo
#               1                                   NaN         Gremio
#               1                  M. Nogueira Barbieri              -
#               1                    D. Aguirre Camblor              -
#               3                                   NaN          Goias
#               4                            E. Pacheco    Ponte Preta
# Quinta-feira  1                           A. Ferreira              -
#               1                V. Luxemburgo da Silva              -
# Sabado        1                                   NaN          Goias
#               1                              A. Fucks          Bahia
#               2                                   NaN   Athletico-PR
#               4                                   NaN         Santos
# Segunda-feira 0                           E. Hartkopp              -
#               3                       M. Ribeiro Cabo          Bahia
# Terça-feira   2                                   NaN          Goias
#
#                                                            arena  \
# dia           mandante_placar
# Domingo       0                                estadio ipatingao
#               0                                orlando scarpelli
#               0                                 moises lucarelli
#               0                                         pacaembu
#               1                estadio joaquim americo guimaraes
#               1                        adelmar da costa carvalho
#               2                                  arena do gremio
#               2                     estadio nacional de brasilia
#               2                                         maracana
#               2                                  arena do gremio
#               2                                   arena castelao
#               2                                         maracana
#               2                                         maracana
#               4                                        beira rio
# Quarta-feira  0                                   ilha do retiro
#               1                                          morumbi
#               1                                         olimpico
#               1                                   allianz parque
#               1                                    vila capanema
#               3                                    serra dourada
#               4                                 moises lucarelli
# Quinta-feira  1                                         maracana
#               1                        itaipava arena fonte nova
# Sabado        1                                        beira rio
#               1                        itaipava arena fonte nova
#               2                                 arena da baixada
#               4                                     vila belmiro
# Segunda-feira 0                            estadio nilton santos
#               3                        itaipava arena fonte nova
# Terça-feira   2                                    serra dourada
#
#                                visitante_placar mandante_estado  \
# dia           mandante_placar
# Domingo       0                               0              MG
#               0                               1              SC
#               0                               0              SP
#               0                               1              SP
#               1                               2              PR
#               1                               1              PE
#               2                               0              RS
#               2                               0              RJ
#               2                               0              RJ
#               2                               0              RS
#               2                               1              CE
#               2                               1              RJ
#               2                               1              RJ
#               4                               1              RS
# Quarta-feira  0                               2              PE
#               1                               0              SP
#               1                               0              RS
#               1                               1              SP
#               1                               1              PR
#               3                               2              GO
#               4                               0              SP
# Quinta-feira  1                               1              RJ
#               1                               1              BA
# Sabado        1                               4              RS
#               1                               0              BA
#               2                               0              PR
#               4                               0              SP
# Segunda-feira 0                               0              RJ
#               3                               0              BA
# Terça-feira   2                               0              GO
#
#                               visitante_estado estado_vencedor
# dia           mandante_placar
# Domingo       0                             SC               -
#               0                             RJ              RJ
#               0                             RS               -
#               0                             RJ              RJ
#               1                             SP              SP
#               1                             SC               -
#               2                             RJ              RS
#               2                             MG              RJ
#               2                             PE              RJ
#               2                             PR              RS
#               2                             BA              CE
#               2                             SP              RJ
#               2                             SC              RJ
#               4                             SP              RS
# Quarta-feira  0                             RJ              RJ
#               1                             RS              SP
#               1                             SP              RS
#               1                             RJ               -
#               1                             SP               -
#               3                             MG              GO
#               4                             PR              SP
# Quinta-feira  1                             SC               -
#               1                             RJ               -
# Sabado        1                             GO              GO
#               1                             AL              BA
#               2                             MG              PR
#               4                             PR              SP
# Segunda-feira 0                             SC               -
#               3                             GO              BA
# Terça-feira   2                             PR              GO

# %%
# Aparantemente, não a quantidade de torcida não infuencia muito.

# %%
# Continuando, temos um método interessante, chamado swaplevel,documentação =  DataFrame.swaplevel(i=- 2, j=- 1, axis=0)
df_sample.swaplevel() # Este método, troca os niveis de hierarquia, dos index, acima vemos o "dia", como primeiro nível.
# Out:
#                                rodada    ID        data   hora       mandante  \
# mandante_placar dia
# 0               Domingo             7  4676  2014-05-25  18:35    Atletico-MG
#                 Domingo            29  5656  2016-10-09  17:02    Figueirense
#                 Domingo            15  5132  2015-07-26  15:59    Ponte Preta
#                 Domingo             1  3850  2012-05-20  16:00    Corinthians
# 1               Domingo            28  5259  2015-09-27  11:00   Athletico-PR
#                 Domingo            17  6294  2018-08-05  19:01          Sport
# 2               Domingo             9  4310  2013-07-28  16:00         Gremio
#                 Domingo            14  5501  2016-07-10  11:00       Flamengo
#                 Domingo            37  4593  2013-12-01  18:00          Vasco
#                 Domingo             4  5405  2016-05-29  18:30         Gremio
#                 Domingo            38  6885  2019-12-08  16:01      Fortaleza
#                 Domingo            22  7481  2021-09-26  16:00     Fluminense
#                 Domingo             4  6539  2019-05-12  11:00       Flamengo
# 4               Domingo            38  3082  2009-12-06  17:00  Internacional
# 0               Quarta-feira       15  3987  2012-08-08  19:30          Sport
# 1               Quarta-feira       32  3023  2009-10-28  21:50      Sao Paulo
#                 Quarta-feira       11  3586  2011-10-05  20:30         Gremio
#                 Quarta-feira       12  6241  2018-06-13  20:59      Palmeiras
#                 Quarta-feira       20  6298  2018-08-22  19:30         Parana
# 3               Quarta-feira       18  2130  2007-08-08  21:45          Goias
# 4               Quarta-feira       15  5889  2017-07-19  20:59    Ponte Preta
# 1               Quinta-feira       30  5284  2015-10-15  19:31          Vasco
#                 Quinta-feira       37  6874  2019-12-05  19:19          Bahia
#                 Sabado             38  1937  2006-12-02  18:10  Internacional
#                 Sabado             17  6667  2019-08-31  17:01          Bahia
# 2               Sabado             33  1462  2005-10-22  16:00   Athletico-PR
# 4               Sabado             28  2604  2008-10-04  18:20         Santos
# 0               Segunda-feira      16  6664  2019-08-26  20:00    Botafogo-RJ
# 3               Segunda-feira       4  5785  2017-06-05  20:00          Bahia
# 2               Terça-feira        38   998  2004-10-26  20:30          Goias
#
#                                    visitante formacao_mandante  \
# mandante_placar dia
# 0               Domingo             Criciuma               NaN
#                 Domingo          Botafogo-RJ           4-2-3-1
#                 Domingo        Internacional           4-2-3-1
#                 Domingo           Fluminense               NaN
# 1               Domingo          Ponte Preta           4-2-3-1
#                 Domingo          Chapecoense           4-2-3-1
# 2               Domingo           Fluminense               NaN
#                 Domingo          Atletico-MG           4-2-3-1
#                 Domingo              Nautico               NaN
#                 Domingo             Coritiba           4-2-3-1
#                 Domingo                Bahia           4-2-3-1
#                 Domingo           Bragantino             4-3-3
#                 Domingo          Chapecoense           4-2-3-1
# 4               Domingo          Santo Andre               NaN
# 0               Quarta-feira           Vasco               NaN
# 1               Quarta-feira   Internacional               NaN
#                 Quarta-feira          Santos               NaN
#                 Quarta-feira        Flamengo           4-2-3-1
#                 Quarta-feira       Sao Paulo           4-1-4-1
# 3               Quarta-feira     Atletico-MG               NaN
# 4               Quarta-feira        Coritiba           4-2-3-1
# 1               Quinta-feira     Chapecoense         4-1-2-1-2
#                 Quinta-feira           Vasco             4-3-3
#                 Sabado                 Goias               NaN
#                 Sabado                   CSA           4-2-3-1
# 2               Sabado           Atletico-MG               NaN
# 4               Sabado          Athletico-PR               NaN
# 0               Segunda-feira    Chapecoense           4-2-3-1
# 3               Segunda-feira    Atletico-GO           4-2-3-1
# 2               Terça-feira     Athletico-PR               NaN
#
#                               formacao_visitante        tecnico_mandante  \
# mandante_placar dia
# 0               Domingo                      NaN                W. Lopes
#                 Domingo                  4-3-1-2      J. Ribeiro Ventura
#                 Domingo                  4-2-2-2      D. Aguirre Camblor
#                 Domingo                      NaN                     NaN
# 1               Domingo                  4-2-3-1       D. Ghidoni Junior
#                 Domingo                  4-1-4-1               G. Kleina
# 2               Domingo                      NaN                     NaN
#                 Domingo                  4-2-3-1   M. de Oliveira Santos
#                 Domingo                      NaN                     NaN
#                 Domingo                  4-2-3-1               G. Kleina
#                 Domingo                    4-3-3      R. Machado Marques
#                 Domingo                  4-2-3-1    M. Nogueira Barbieri
#                 Domingo                  4-2-3-1   N. da Silveira Júnior
# 4               Domingo                      NaN                     NaN
# 0               Quarta-feira                 NaN                     NaN
# 1               Quarta-feira                 NaN                     NaN
#                 Quarta-feira                 NaN                     NaN
#                 Quarta-feira             4-1-4-1    M. Nogueira Barbieri
#                 Quarta-feira             4-2-3-1      D. Aguirre Camblor
# 3               Quarta-feira                 NaN                     NaN
# 4               Quarta-feira             4-1-4-1              E. Pacheco
# 1               Quinta-feira             4-2-3-1             A. Ferreira
#                 Quinta-feira               4-3-3  V. Luxemburgo da Silva
#                 Sabado                       NaN                     NaN
#                 Sabado                     4-4-2                A. Fucks
# 2               Sabado                       NaN                     NaN
# 4               Sabado                       NaN                     NaN
# 0               Segunda-feira            4-2-3-1             E. Hartkopp
# 3               Segunda-feira            4-2-3-1         M. Ribeiro Cabo
# 2               Terça-feira                  NaN                     NaN
#
#                                     tecnico_visitante       vencedor  \
# mandante_placar dia
# 0               Domingo                      W. Lopes              -
#                 Domingo            J. Ribeiro Ventura    Botafogo-RJ
#                 Domingo            D. Aguirre Camblor              -
#                 Domingo                           NaN     Fluminense
# 1               Domingo             D. Ghidoni Junior    Ponte Preta
#                 Domingo                     G. Kleina              -
# 2               Domingo                           NaN         Gremio
#                 Domingo         M. de Oliveira Santos       Flamengo
#                 Domingo                           NaN          Vasco
#                 Domingo                     G. Kleina         Gremio
#                 Domingo            R. Machado Marques      Fortaleza
#                 Domingo          M. Nogueira Barbieri     Fluminense
#                 Domingo         N. da Silveira Júnior       Flamengo
# 4               Domingo                           NaN  Internacional
# 0               Quarta-feira                      NaN          Vasco
# 1               Quarta-feira                      NaN      Sao Paulo
#                 Quarta-feira                      NaN         Gremio
#                 Quarta-feira     M. Nogueira Barbieri              -
#                 Quarta-feira       D. Aguirre Camblor              -
# 3               Quarta-feira                      NaN          Goias
# 4               Quarta-feira               E. Pacheco    Ponte Preta
# 1               Quinta-feira              A. Ferreira              -
#                 Quinta-feira   V. Luxemburgo da Silva              -
#                 Sabado                            NaN          Goias
#                 Sabado                       A. Fucks          Bahia
# 2               Sabado                            NaN   Athletico-PR
# 4               Sabado                            NaN         Santos
# 0               Segunda-feira             E. Hartkopp              -
# 3               Segunda-feira         M. Ribeiro Cabo          Bahia
# 2               Terça-feira                       NaN          Goias
#
#                                                            arena  \
# mandante_placar dia
# 0               Domingo                        estadio ipatingao
#                 Domingo                        orlando scarpelli
#                 Domingo                         moises lucarelli
#                 Domingo                                 pacaembu
# 1               Domingo        estadio joaquim americo guimaraes
#                 Domingo                adelmar da costa carvalho
# 2               Domingo                          arena do gremio
#                 Domingo             estadio nacional de brasilia
#                 Domingo                                 maracana
#                 Domingo                          arena do gremio
#                 Domingo                           arena castelao
#                 Domingo                                 maracana
#                 Domingo                                 maracana
# 4               Domingo                                beira rio
# 0               Quarta-feira                      ilha do retiro
# 1               Quarta-feira                             morumbi
#                 Quarta-feira                            olimpico
#                 Quarta-feira                      allianz parque
#                 Quarta-feira                       vila capanema
# 3               Quarta-feira                       serra dourada
# 4               Quarta-feira                    moises lucarelli
# 1               Quinta-feira                            maracana
#                 Quinta-feira           itaipava arena fonte nova
#                 Sabado                                 beira rio
#                 Sabado                 itaipava arena fonte nova
# 2               Sabado                          arena da baixada
# 4               Sabado                              vila belmiro
# 0               Segunda-feira              estadio nilton santos
# 3               Segunda-feira          itaipava arena fonte nova
# 2               Terça-feira                        serra dourada
#
#                                visitante_placar mandante_estado  \
# mandante_placar dia
# 0               Domingo                       0              MG
#                 Domingo                       1              SC
#                 Domingo                       0              SP
#                 Domingo                       1              SP
# 1               Domingo                       2              PR
#                 Domingo                       1              PE
# 2               Domingo                       0              RS
#                 Domingo                       0              RJ
#                 Domingo                       0              RJ
#                 Domingo                       0              RS
#                 Domingo                       1              CE
#                 Domingo                       1              RJ
#                 Domingo                       1              RJ
# 4               Domingo                       1              RS
# 0               Quarta-feira                  2              PE
# 1               Quarta-feira                  0              SP
#                 Quarta-feira                  0              RS
#                 Quarta-feira                  1              SP
#                 Quarta-feira                  1              PR
# 3               Quarta-feira                  2              GO
# 4               Quarta-feira                  0              SP
# 1               Quinta-feira                  1              RJ
#                 Quinta-feira                  1              BA
#                 Sabado                        4              RS
#                 Sabado                        0              BA
# 2               Sabado                        0              PR
# 4               Sabado                        0              SP
# 0               Segunda-feira                 0              RJ
# 3               Segunda-feira                 0              BA
# 2               Terça-feira                   0              GO
#
#                               visitante_estado estado_vencedor
# mandante_placar dia
# 0               Domingo                     SC               -
#                 Domingo                     RJ              RJ
#                 Domingo                     RS               -
#                 Domingo                     RJ              RJ
# 1               Domingo                     SP              SP
#                 Domingo                     SC               -
# 2               Domingo                     RJ              RS
#                 Domingo                     MG              RJ
#                 Domingo                     PE              RJ
#                 Domingo                     PR              RS
#                 Domingo                     BA              CE
#                 Domingo                     SP              RJ
#                 Domingo                     SC              RJ
# 4               Domingo                     SP              RS
# 0               Quarta-feira                RJ              RJ
# 1               Quarta-feira                RS              SP
#                 Quarta-feira                SP              RS
#                 Quarta-feira                RJ               -
#                 Quarta-feira                SP               -
# 3               Quarta-feira                MG              GO
# 4               Quarta-feira                PR              SP
# 1               Quinta-feira                SC               -
#                 Quinta-feira                RJ               -
#                 Sabado                      GO              GO
#                 Sabado                      AL              BA
# 2               Sabado                      MG              PR
# 4               Sabado                      PR              SP
# 0               Segunda-feira               SC               -
# 3               Segunda-feira               GO              BA
# 2               Terça-feira                 PR              GO

# %% [markdown]
# **Manipulando strings**

# %%
nome = "Leo"

# %%
type(nome) # Tipo da variável.
# Out:
# str

# %%
len(nome) # Tamanho da palavra
# Out:
# 3

# %%
nome.lower() # Todas as letras minúsculas.
# Out:
# 'leo'

# %%
nome.title() # Primeira letra de cada palavra em maiuscula.
# Out:
# 'Leo'

# %%
# Existem inumeras formas de manipular, com as funções built-in functions, e não é necessário decorar todas, basta saber o que precisa 
# E a forma de procurar a função que realiza o que voce precisa no dado momento.

# %%
nome.split(" ") # Quebrar o espaço vazio. Para palavras compostas. separando os elementos.
# Out:
# ['Leo']

# %%
# substituir palavras 
time = "São Paulo"

# %%
time.replace("Paulo", "Tricolorrrrr") # Passamos primeiro parâmetro a palavra a ser substituida e o segundo a palavara substituta.
# Out:
# 'São Tricolorrrrr'
